# %%
import sys

# %%
#!/usr/bin/env python

import re
import sys
import json
import time
import random
import argparse
import networkx
from pathlib import Path

# %% [markdown]
# - https://github.com/ORCID/python-orcid
# - https://github.com/scholarly-python-package/scholarly
# - https://github.com/fabiobatalha/crossrefapi

# %%
# !{sys.executable} -m pip install crossrefapi orcid scholarly[tor]

# %%
# Import necessary libraries
import requests
from scholarly import scholarly
import orcid 
import crossref

# %%
# Define function to retrieve DOIs for all papers published by a researcher using their ORCID or Google Scholar profile page
def get_paper_dois(profile_page):
    
    # Define empty list to store DOIs
    dois = []
    
    # Check if the profile page is for ORCID or Google Scholar
    if "orcid" in profile_page:
        
        # Define API endpoint and headers
        endpoint = f"https://pub.orcid.org/v3.0/{profile_page.split('/')[-1]}/works"
        headers = {"Accept": "application/vnd.citationstyles.csl+json", "Authorization": "Bearer <access_token>"}
        
        # Send GET request to API endpoint
        response = requests.get(endpoint, headers=headers)
        
        # Check if response was successful
        if response.status_code == 200:
            
            # Extract list of DOIs from response
            works = response.json()["group"]
            for work in works:
                doi = work["external-ids"]["external-id"][0]["external-id-value"]
                dois.append(doi)
            
        else:
            print("Error retrieving data from ORCID API")
            
    elif "scholar.google" in profile_page:
        
        # Retrieve Google Scholar profile using the scholarly package
        search_query = scholarly.search_author_id(profile_page.split('=')[-1])
        profile = scholarly.fill(next(search_query))
        
        # Extract list of DOIs from profile
        for pub in profile.publications:
            if pub.bib.get("doi"):
                dois.append(pub.bib["doi"])
            else:
                # Try to search for the DOI using gslookup
                search_query = f"{pub.bib['title']} {pub.bib['author']}"
                search_results = scholarly.gscholar(search_query)
                for result in search_results:
                    if pub.bib["title"] == result["title"] and pub.bib["author"] == result["author"]:
                        if result.get("eprint"):
                            # Extract DOI from eprint URL
                            doi = result["eprint"].split("/")[-1]
                            if doi.startswith("10."):
                                dois.append(doi)
                        elif result.get("url"):
                            # Extract DOI from URL
                            doi = result["url"].split("/")[-1]
                            if doi.startswith("10."):
                                dois.append(doi)                
    
    else:
        print("Invalid profile page. Please provide a valid ORCID or Google Scholar profile page.")
    
    return dois

# %%
orcid_profile = 'https://orcid.org/0000-0001-6781-893X'

# %%
orcid_url = f'{orcid_profile}/worksExtendedPage.json?offset=0&sort=date&sortAsc=false&pageSize=50'

# %%
resp = requests.get(orcid_url)

# %%
resp.ok
# Out:
# True

# %%
resp.status_code
# Out:
# 200

# %%
resp.json()
# Out:
# {'nextOffset': 50,
#  'totalGroups': 21,
#  'groups': [{'activePutCode': 123746668,
#    'defaultPutCode': 123746668,
#    'groupId': 0,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1080/15592294.2020.1748917',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': 'https://doi.org/10.1080/15592294.2020.1748917',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1080/15592294.2020.1748917',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': {'errors': [],
#       'value': 'https://doi.org/10.1080/15592294.2020.1748917',
#       'required': False,
#       'getRequiredMessage': None}}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': '10',
#       'day': '02',
#       'year': '2020',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '123746668',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': 'Epigenetics',
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Idoia Blanco-Luquin'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Blanca Acha'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Amaya Urdánoz-Casado'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Javier Sánchez-Ruiz De Gordoa'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Janire Vicuña-Urriza'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Miren Roldán'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Alberto Labarga'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'María Victoria Zelaya'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Carolina Cabello'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Iván Méndez-López'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Maite Mendioroz'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': None,
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 11,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1080/15592294.2020.1748917',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': 'https://doi.org/10.1080/15592294.2020.1748917',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1080/15592294.2020.1748917',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': {'errors': [],
#         'value': 'https://doi.org/10.1080/15592294.2020.1748917',
#         'required': False,
#         'getRequiredMessage': None}}],
#      'source': '0000-0001-9884-1913',
#      'sourceName': 'Crossref',
#      'assertionOriginOrcid': None,
#      'assertionOriginClientId': None,
#      'assertionOriginName': None,
#      'title': {'errors': [],
#       'value': 'Early epigenetic changes of Alzheimer’s disease in the human hippocampus',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '11',
#       'day': '29',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '11',
#       'day': '29',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 19074127,
#    'defaultPutCode': 19074127,
#    'groupId': 1,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1002/prca.201400127',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': None,
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1002/prca.201400127',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': {'errors': [],
#       'value': 'https://doi.org/10.1002/prca.201400127',
#       'required': False,
#       'getRequiredMessage': None}},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '25418211',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': None,
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '25418211',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': {'errors': [],
#       'value': 'https://pubmed.ncbi.nlm.nih.gov/25418211',
#       'required': False,
#       'getRequiredMessage': None}}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': '10',
#       'day': None,
#       'year': '2015',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '19074127',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Fernandez-Irigoyen J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Labarga A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Zabaleta A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'de Morentin XM'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Perez-Valderrama E'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Zelaya MV'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Santamaria E'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 7,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '25418211',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': None,
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '25418211',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': {'errors': [],
#         'value': 'https://pubmed.ncbi.nlm.nih.gov/25418211',
#         'required': False,
#         'getRequiredMessage': None}},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1002/prca.201400127',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': None,
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1002/prca.201400127',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': {'errors': [],
#         'value': 'https://doi.org/10.1002/prca.201400127',
#         'required': False,
#         'getRequiredMessage': None}}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'Toward defining the anatomo-proteomic puzzle of the human brain: An integrative analysis.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '10',
#       'day': '8',
#       'year': '2015',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '24',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 13493759,
#    'defaultPutCode': 13493759,
#    'groupId': 2,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': 'PMC3598643',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmc',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '3598643',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '23398680',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '23398680',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1186/2041-1480-4-6',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1186/2041-1480-4-6',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': None,
#       'day': None,
#       'year': '2013',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '13493759',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Katayama T'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Wilkinson MD'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Micklem G'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Kawashima S'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Yamaguchi A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Nakao M'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Yamamoto Y'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Okamoto S'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Oouchida K'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Chun HW'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Aerts J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Afzal H'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Antezana E'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Arakawa K'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Aranda B'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Belleau F'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Bolleman J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Bonnal RJ'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Chapman B'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Cock PJ'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 20,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '23398680',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '23398680',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': 'PMC3598643',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmc',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '3598643',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1186/2041-1480-4-6',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1186/2041-1480-4-6',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'The 3rd DBCLS BioHackathon: improving life science data integration with Semantic Web technologies.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '8',
#       'day': '29',
#       'year': '2014',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '23',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 13493758,
#    'defaultPutCode': 13493758,
#    'groupId': 3,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '23222711',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '23222711',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1038/onc.2012.507',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1038/onc.2012.507',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': '10',
#       'day': None,
#       'year': '2013',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '13493758',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Rubio R'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Gutierrez-Aranda I'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Sáez-Castillo AI'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Labarga A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Rosu-Myles M'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Gonzalez-Garcia S'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Toribio ML'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Menendez P'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Rodriguez R'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 9,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '23222711',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '23222711',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1038/onc.2012.507',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1038/onc.2012.507',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'The differentiation stage of p53-Rb-deficient bone marrow mesenchymal stem cells imposes the phenotype of in vivo sarcoma development.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '8',
#       'day': '29',
#       'year': '2014',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '23',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 13493760,
#    'defaultPutCode': 13493760,
#    'groupId': 4,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1073/pnas.1201904109',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1073/pnas.1201904109',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '22797899',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '22797899',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': 'PMC3409785',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmc',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '3409785',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': '07',
#       'day': None,
#       'year': '2012',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '13493760',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Ball MP'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Thakuria JV'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Zaranek AW'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Clegg T'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Rosenbaum AM'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Wu X'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Angrist M'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Bhak J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Bobe J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Callow MJ'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Cano C'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Chou MF'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Chung WK'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Douglas SM'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Estep PW'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Gore A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Hulick P'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Labarga A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Lee JH'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Lunshof JE'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 20,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '22797899',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '22797899',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': 'PMC3409785',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmc',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '3409785',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1073/pnas.1201904109',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1073/pnas.1201904109',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'A public resource facilitating clinical use of genomes.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '8',
#       'day': '29',
#       'year': '2014',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '23',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 13493761,
#    'defaultPutCode': 13493761,
#    'groupId': 5,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1186/2041-1480-2-4',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1186/2041-1480-2-4',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '21806842',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '21806842',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': 'PMC3170566',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmc',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '3170566',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': None,
#       'day': None,
#       'year': '2011',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '13493761',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Katayama T'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Wilkinson MD'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Vos R'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Kawashima T'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Kawashima S'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Nakao M'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Yamamoto Y'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Chun HW'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Yamaguchi A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
# ...
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Iriarte J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Malanda A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Artieda J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 6,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '12478393',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '12478393',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1007/s00221-002-1255-x',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1007/s00221-002-1255-x',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'Movement-related changes in cortical oscillatory activity in ballistic, sustained and negative movements.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '8',
#       'day': '29',
#       'year': '2014',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '23',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 13493775,
#    'defaultPutCode': 13493775,
#    'groupId': 19,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '12359316',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '12359316',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1016/S0304-3940(02)00825-X',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1016/s0304-3940(02)00825-x',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': '10',
#       'day': None,
#       'year': '2002',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '13493775',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Alegre M'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Labarga A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Gurtubay IG'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Iriarte J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Malanda A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Artieda J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 6,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '12359316',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '12359316',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1016/S0304-3940(02)00825-X',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1016/s0304-3940(02)00825-x',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'Beta electroencephalograph changes during passive movements: sensory afferences contribute to beta event-related desynchronization in humans.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '8',
#       'day': '29',
#       'year': '2014',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '23',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]},
#   {'activePutCode': 13493776,
#    'defaultPutCode': 13493776,
#    'groupId': 20,
#    'activeVisibility': 'PUBLIC',
#    'userVersionPresent': False,
#    'externalIdentifiers': [{'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '10.1016/S1388-2457(01)00557-0',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'doi',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '10.1016/s1388-2457(01)00557-0',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None},
#     {'errors': [],
#      'externalIdentifierId': {'errors': [],
#       'value': '11516733',
#       'required': True,
#       'getRequiredMessage': None},
#      'externalIdentifierType': {'errors': [],
#       'value': 'pmid',
#       'required': True,
#       'getRequiredMessage': None},
#      'url': {'errors': [],
#       'value': '',
#       'required': True,
#       'getRequiredMessage': None},
#      'relationship': {'errors': [],
#       'value': 'self',
#       'required': True,
#       'getRequiredMessage': None},
#      'normalized': {'errors': [],
#       'value': '11516733',
#       'required': False,
#       'getRequiredMessage': None},
#      'normalizedUrl': None}],
#    'works': [{'visibility': {'errors': [],
#       'required': True,
#       'getRequiredMessage': None,
#       'visibility': 'PUBLIC'},
#      'errors': [],
#      'publicationDate': {'errors': [],
#       'month': '07',
#       'day': None,
#       'year': '2001',
#       'required': True,
#       'getRequiredMessage': None},
#      'putCode': {'errors': [],
#       'value': '13493776',
#       'required': True,
#       'getRequiredMessage': None},
#      'shortDescription': None,
#      'url': None,
#      'journalTitle': {'errors': [],
#       'value': None,
#       'required': True,
#       'getRequiredMessage': None},
#      'languageCode': None,
#      'languageName': None,
#      'citation': None,
#      'countryCode': None,
#      'countryName': None,
#      'contributors': None,
#      'contributorsGroupedByOrcid': [{'contributorOrcid': None,
#        'creditName': {'content': 'Gurtubay IG'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Alegre M'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Labarga A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Malanda A'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Iriarte J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]},
#       {'contributorOrcid': None,
#        'creditName': {'content': 'Artieda J'},
#        'contributorEmail': None,
#        'contributorAttributes': None,
#        'rolesAndSequences': [{'contributorSequence': 'FIRST',
#          'contributorRole': 'author'}]}],
#      'numberOfContributors': 6,
#      'workExternalIdentifiers': [{'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '11516733',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'pmid',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '11516733',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None},
#       {'errors': [],
#        'externalIdentifierId': {'errors': [],
#         'value': '10.1016/S1388-2457(01)00557-0',
#         'required': True,
#         'getRequiredMessage': None},
#        'externalIdentifierType': {'errors': [],
#         'value': 'doi',
#         'required': True,
#         'getRequiredMessage': None},
#        'url': {'errors': [],
#         'value': '',
#         'required': True,
#         'getRequiredMessage': None},
#        'relationship': {'errors': [],
#         'value': 'self',
#         'required': True,
#         'getRequiredMessage': None},
#        'normalized': {'errors': [],
#         'value': '10.1016/s1388-2457(01)00557-0',
#         'required': False,
#         'getRequiredMessage': None},
#        'normalizedUrl': None}],
#      'source': '0000-0002-9157-3431',
#      'sourceName': 'Europe PubMed Central',
#      'assertionOriginOrcid': '0000-0001-6781-893X',
#      'assertionOriginClientId': None,
#      'assertionOriginName': 'Alberto Labarga',
#      'title': {'errors': [],
#       'value': 'Gamma band activity in an auditory oddball paradigm studied with the wavelet transform.',
#       'required': True,
#       'getRequiredMessage': None},
#      'subtitle': None,
#      'translatedTitle': None,
#      'workCategory': None,
#      'workType': {'errors': [],
#       'value': 'journal-article',
#       'required': True,
#       'getRequiredMessage': None},
#      'dateSortString': None,
#      'createdDate': {'errors': [],
#       'month': '8',
#       'day': '29',
#       'year': '2014',
#       'required': True,
#       'getRequiredMessage': None},
#      'lastModified': {'errors': [],
#       'month': '5',
#       'day': '23',
#       'year': '2022',
#       'required': True,
#       'getRequiredMessage': None},
#      'userSource': False}]}]}

# %%
google_scholar_profile='https://scholar.google.com/citations?user=gvzAHzcAAAAJ'

# %%
Path(google_scholar_profile).parts
# Out:
# ('https:', 'scholar.google.com', 'citations?user=gvzAHzcAAAAJ')

# %%
google_scholar_id = google_scholar_profile.split('=')[-1]

# %%
author = scholarly.search_author_id(google_scholar_id)

# %%
from scholarly import ProxyGenerator

# Set up a ProxyGenerator object to use free proxies
# This needs to be done only once per session
pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)

# %%
# Retrieve the author's data, fill-in, and print
search_query = scholarly.search_author('Alberto Labarga')
author = scholarly.fill(next(search_query))

# %%
author.keys()
# Out:
# dict_keys(['container_type', 'filled', 'source', 'scholar_id', 'url_picture', 'name', 'affiliation', 'email_domain', 'interests', 'citedby', 'organization', 'homepage', 'citedby5y', 'hindex', 'hindex5y', 'i10index', 'i10index5y', 'cites_per_year', 'coauthors', 'publications', 'public_access'])

# %%
author["name"]
# Out:
# 'Alberto Labarga'

# %%
author["scholar_id"]
# Out:
# 'gvzAHzcAAAAJ'

# %%
for pub in author['publications']:
    title = pub['bib']['title']
    print(title)
# Out:
# New developments in the InterPro database
# Web services at the European bioinformatics institute
# A public resource facilitating clinical use of genomes
# Beta electroencephalograph changes during passive movements: sensory afferences contribute to beta event-related desynchronization in humans
# The Semantic Automated Discovery and Integration (SADI) web service design-pattern, API and reference implementation
# Frontal and central oscillatory changes related to different aspects of the motor process: a study in go/no-go paradigms
# Movement-related changes in cortical oscillatory activity in ballistic, sustained and negative movements
# Alpha and beta oscillatory changes during stimulus-induced movement paradigms: effect of stimulus predictability
# Gamma band activity in an auditory oddball paradigm studied with the wavelet transform
# Alpha and beta oscillatory activity during a sequence of two movements
# Priorities for nucleotide trace, sequence and annotation data capture at the Ensembl Trace Archive and the EMBL Nucleotide Sequence Database
# A gene signature of 8 genes could identify the risk of recurrence and progression in Dukes' B colon cancer patients
# Gamma band responses to target and non-target auditory stimuli in humans
# DNA methylation signature of human hippocampus in Alzheimer’s disease is linked to neurogenesis
# A tree-based conservation scoring method for short linear motifs in multiple alignments of protein sequences
# The 3rd DBCLS BioHackathon: improving life science data integration with Semantic Web technologies
# GARBAN: genomic analysis and rapid biological annotation of cDNA microarray and proteomic data
# Experience using web services for biological sequence analysis
# Dasty2, an Ajax protein DAS client
# Semantic web and social web heading towards living documents in the life sciences
# Epigenetic response to mindfulness in peripheral blood leukocytes involves genes linked to common human diseases
# The 2nd DBCLS BioHackathon: interoperable bioinformatics Web services for integrated applications
# Mass spectrometry-based proteomic profiling of thrombotic material obtained by endovascular thrombectomy in patients with ischemic stroke
# Circular RNA expression profile in blood according to ischemic stroke etiology
# Telomere length correlates with subtelomeric DNA methylation in long-term mindfulness practitioners
# Toward defining the anatomo‐proteomic puzzle of the human brain: An integrative analysis
# Early epigenetic changes of Alzheimer’s disease in the human hippocampus
# Collaborative semi-automatic annotation of the biomedical literature
# Plataforma para el aprendizaje de algoritmos computacionales y su aplicación a las ciencias de la vida
# Social and Semantic Web Technologies for the Text-To-Knowledge Translation Process in Biomedicine
# Annotating Atomic Components of Papers in Digital Libraries: The Semantic and Social Web Heading towards a Living Document Supporting eSciences.
# Análisis de Componentes Independientes en el Estudio de Potenciales Auditivos P300
# Brain Proteomics
# Semantic Web and Social Web heading towards Living Documents in the Life Sciences.
# Journal of Biomedical Semantics
# Clasificación de Señales Encefalográficas con Redes Neuronales
# Telomere length correlates with subtelomeric DNA methylation in long-term mindfulness practitioners
# DNA methylation profile in the human hippocampus identifies involvement of genes essential in neurogenesis in Alzheimer's disease
# Genome-wide DNA methylation profiling in peripheral blood from different TOAST-subtypes stroke patients.(P4. 3-046)
# Gene-specific DNA methylation is related to drug treatment in Alzheimer's disease patients
# Periodismo de datos y la visualización de datos abiertos
# y Neuromusculares.
# Alpha and beta oscillatory activity during a sequence of two movements
# Sleep stages and oscillatory cortical changes during the periodic limb movement
# Guidelines for the submission of manuscripts v
# Analisis mediante la utilizacion de transformadas wavelet de la actividad a 40 Hz en paradigmas auditivos de P300
# Cambios en la actividad oscilatoria cortical rapida durante la realizacion de movimientos voluntarios balisticos simples
# ESTUDIO DE POTENCIALES AUDITIVOS P300
# NOTAS INFORMATIVAS/RESÚMENES DE TRABAJOS CIENTÍFICOS PUBLICADOS EN OTRAS REVISTAS

# %%
pub = author['publications'][0]

# %%
len(author['publications'])
# Out:
# 49

# %% [markdown]
# ## Crossref

# %%
from crossref.restful import Works

# %%
works = Works()

# %%
pub
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#  'bib': {'title': 'New developments in the InterPro database',
#   'pub_year': '2007',
#   'citation': 'Nucleic acids research 35 (suppl_1), D224-D228, 2007'},
#  'filled': False,
#  'author_pub_id': 'gvzAHzcAAAAJ:u5HHmVD_uO8C',
#  'num_citations': 594,
#  'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17463171523175817476',
#  'cites_id': ['17463171523175817476']}

# %%
results = [work for work in works.query(bibliographic=pub['bib']['title'], author=author['name'])]

# %%
next(works.query(bibliographic=pub['bib']['title'], author=author['name']))

# %%
works.doi('10.1590/0102-311x00133115')

# %%
from urllib.parse import quote

# %%
 # Try to search for the DOI using Crossref
title = pub["bib"]["title"]
author = pub["bib"]["author"][0]

# %%
def get_doi(title, author):
    query = f"title:{quote(title)}+AND+author:{quote(author)}"
    response = requests.get(f"https://api.crossref.org/works?query={query}&mailto=alberto.labarga@bsc.es")
    if response.status_code == 200:
        data = response.json()
        return data["message"]["items"][0].get('URL')
    return None

# %%
get_doi(title, author)
# Out:
# 'http://dx.doi.org/10.1093/nar/gkm291'

# %%
f"https://api.crossref.org/works?query={query}"
# Out:
# 'https://api.crossref.org/works?query=title:Web%20services%20at%20the%20European%20bioinformatics%20institute+AND+author:A%20Labarga'

# %%
[it.get('URL') for it in data["message"]["items"]]
# Out:
# ['http://dx.doi.org/10.1093/nar/gkm291',
#  'http://dx.doi.org/10.1093/bib/4.4.332',
#  'http://dx.doi.org/10.1002/cpbi.74',
#  'http://dx.doi.org/10.1002/0471650129.dob0196',
#  'http://dx.doi.org/10.1016/s0076-6879(96)66003-0',
#  'http://dx.doi.org/10.1093/bib/bbn029',
#  'http://dx.doi.org/10.1186/1471-2105-9-229',
#  'http://dx.doi.org/10.1093/nar/gkp302',
#  'http://dx.doi.org/10.1042/bio02604033',
#  'http://dx.doi.org/10.1007/0-387-27478-2_9',
#  'http://dx.doi.org/10.1007/978-94-6265-383-2_2',
#  'http://dx.doi.org/10.1093/ww/9780199540884.013.37638',
#  'http://dx.doi.org/10.1093/nar/gkh405',
#  'http://dx.doi.org/10.1093/ww/9780199540884.013.u37638',
#  'http://dx.doi.org/10.1186/s12859-019-3159-9',
#  'http://dx.doi.org/10.1385/0-89603-358-9:303',
#  'http://dx.doi.org/10.1093/bioinformatics/btn387',
#  'http://dx.doi.org/10.1093/nar/24.1.6',
#  'http://dx.doi.org/10.1093/bib/bbq023',
#  'http://dx.doi.org/10.1042/bio03604039']

# %%
data["message"]["items"][0].get('URL')
# Out:
# 'http://dx.doi.org/10.1093/nar/gkm291'

# %%
if data["message"]["total-results"] > 0:
    doi = data["message"]["items"][0].get("DOI")
    if doi:
        dois.append(doi)

# %%
get_paper_dois(google_scholar_profile).get('URL')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 get_paper_dois(google_scholar_profile)
#
# Cell In[100], line 33, in get_paper_dois(profile_page)
#      29 elif "scholar.google" in profile_page:
#      30
#      31     # Retrieve Google Scholar profile using the scholarly package
#      32     search_query = scholarly.search_author_id(profile_page.split('=')[-1])
# ---> 33     profile = scholarly.fill(next(search_query))
#      35     # Extract list of DOIs from profile
#      36     for pub in profile.publications:
#
# TypeError: 'dict' object is not an iterator

# %%
get_paper_dois(orcid_url)
# Out:
# Error retrieving data from ORCID API
# []

# %%
'''
Opencitations Network
fetching citation data of a specific research paper using COCI REST API
'''

#user input
doi=input("enter doi, ex- 10.1021/ci500020m : ")


doilist=[doi] #list of all DOIs in network
lst = []

for z in doilist:
    res=requests.get(f'https://opencitations.net/index/coci/api/v1/citations/{z}')
    datax = res.json()
    dlen=len(datax)
    n=dlen
    for j in range(n):
        data1x=datax[j]
        dfy=list(data1x.keys())
        dfx=list(data1x.values())
        datf=pd.DataFrame({"value":dfx,"key":dfy})
        lst.append(dfx)
        y=datf.loc[datf['key'] == 'citing', 'value'].iloc[0]
        doilist.append(y)
        
df = pd.DataFrame(lst, columns=dfy)

# %% [markdown]
# ## Visualisation....................................

# %%
import networkx as nx
from pyvis.network import Network
import IPython

G = nx.from_pandas_edgelist(df,'cited','citing')
net=Network(height='1000px',width='100%',bgcolor='#222222',font_color='white',directed='True') #add layout = 'True' for heirarchical tree layout
net.from_nx(G)
net.save_graph('coci.html')
IPython.display.HTML(filename='coci.html')

# %%
#extracting metadata of all the DOIs in the network for further data analysis

metalist=[] # contains metadata of all DOIs in network
for k in doilist:
    metares=requests.get(f'https://opencitations.net/index/coci/api/v1/metadata/{k}')
    datam=metares.json()
    metalist.append(datam)

#extracting urls of all the open access DOIs in the network

from urlextract import URLExtract
metastr=str(metalist)
extractor = URLExtract()
urls = extractor.find_urls(metastr)
